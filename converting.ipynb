# %% [markdown]
# ## Average Earning Index

# %%
#pandas library for data cleaning
import pandas as pd

# %%
#Open and read Average Earning Index Quarterly dataset
average_earning_index = pd.read_csv('C:\\Users\\Nisa\\Documents\\average_weekly_earning (quarterly).csv')

# %%
#Test to open dataset
average_earning_index.head()
# Out:
#      Date  Index
# 0  Jan-90   62.0
# 1  Apr-90   63.7
# 2  Jul-90   64.6
# 3  Sep-90   66.3
# 4  Jan-91   67.3

# %%
#Convert to period months
average_earning_index['Date'] = pd.to_datetime(average_earning_index['Date']).dt.to_period('M')

# %%
average_earning_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    40 non-null     period[M]
#  1   Index   40 non-null     float64
# dtypes: float64(1), period[M](1)
# memory usage: 768.0 bytes

# %%
#set Date as Index and resample
ave_earn_in_new = average_earning_index.set_index('Date').resample('M').interpolate()

# %%
ave_earn_in_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 117 entries, 1990-01 to 1999-09
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   117 non-null    float64
# dtypes: float64(1)
# memory usage: 1.8 KB

# %%
#setting Date as index 
ave_earn_in_new['Date'] = ave_earn_in_new.index

# %%
#print converted quarterly data to monthly
ave_earn_in_new
# Out:
#              Index     Date
# Date
# 1990-01  62.000000  1990-01
# 1990-02  62.566667  1990-02
# 1990-03  63.133333  1990-03
# 1990-04  63.700000  1990-04
# 1990-05  64.000000  1990-05
# ...            ...      ...
# 1999-05  94.466667  1999-05
# 1999-06  94.333333  1999-06
# 1999-07  94.200000  1999-07
# 1999-08  95.350000  1999-08
# 1999-09  96.500000  1999-09
#
# [117 rows x 2 columns]

# %%
#attaching rest of AEI monthly data to the data set that has been cleaned 
ave_earn_index_bymonth = pd.read_csv('C:\\Users\\Nisa\\Documents\\average_weekly_earning (monthly).csv')

# %%
ave_earn_index_bymonth.head()
# Out:
#        Date  Index
# 0  1-Jan-00   98.8
# 1  1-Feb-00  101.1
# 2  1-Mar-00  104.9
# 3  1-Apr-00   98.5
# 4  1-May-00   98.4

# %%
#Convert to period month 
ave_earn_index_bymonth['Date'] = pd.to_datetime(ave_earn_index_bymonth['Date']).dt.to_period('M')

# %%
ave_earn_index_bymonth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    261 non-null    period[M]
#  1   Index   261 non-null    float64
# dtypes: float64(1), period[M](1)
# memory usage: 4.2 KB

# %%
#set Date as Index and resample
ave_earn_in_month_new = ave_earn_index_bymonth.set_index('Date').resample('M').interpolate()

# %%
ave_earn_in_month_new['Date'] = ave_earn_in_month_new.index

# %%
#print the data
ave_earn_in_month_new
# Out:
#          Index     Date
# Date
# 2000-01   98.8  2000-01
# 2000-02  101.1  2000-02
# 2000-03  104.9  2000-03
# 2000-04   98.5  2000-04
# 2000-05   98.4  2000-05
# ...        ...      ...
# 2021-05  183.1  2021-05
# 2021-06  183.6  2021-06
# 2021-07  182.8  2021-07
# 2021-08  181.7  2021-08
# 2021-09  181.3  2021-09
#
# [261 rows x 2 columns]

# %%
#to merge the data ave_earn_in_month_new and ave_earn_in_new to become one data set
concatenate_AEI = pd.concat([ave_earn_in_new, ave_earn_in_month_new])

# %%
#print and check if merge data correctly
concatenate_AEI
# Out:
#               Index     Date
# Date
# 1990-01   62.000000  1990-01
# 1990-02   62.566667  1990-02
# 1990-03   63.133333  1990-03
# 1990-04   63.700000  1990-04
# 1990-05   64.000000  1990-05
# ...             ...      ...
# 2021-05  183.100000  2021-05
# 2021-06  183.600000  2021-06
# 2021-07  182.800000  2021-07
# 2021-08  181.700000  2021-08
# 2021-09  181.300000  2021-09
#
# [378 rows x 2 columns]

# %% [markdown]
# ## Retail Price Index

# %%
#Open and read Retail Price Index Monthly dataset
retail_price_index = pd.read_csv('C:\\Users\\Nisa\\Documents\\rpi (monthly).csv')

# %%
retail_price_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    384 non-null    object
#  1   %       384 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.1+ KB

# %%
retail_price_index.head()
# Out:
#        Date    %
# 0  1990 JAN  7.7
# 1  1990 FEB  7.5
# 2  1990 MAR  8.1
# 3  1990 APR  9.4
# 4  1990 MAY  9.7

# %%
retail_price_index['Date'] = pd.to_datetime(retail_price_index['Date']).dt.to_period('M')

# %%
#set Date as Index and resample
retail_price_index_new = retail_price_index.set_index('Date').resample('M').interpolate()

# %%
retail_price_index_new['Date'] = retail_price_index_new.index

# %%
retail_price_index_new
# Out:
#            %     Date
# Date
# 1990-01  7.7  1990-01
# 1990-02  7.5  1990-02
# 1990-03  8.1  1990-03
# 1990-04  9.4  1990-04
# 1990-05  9.7  1990-05
# ...      ...      ...
# 2021-08  4.8  2021-08
# 2021-09  4.9  2021-09
# 2021-10  6.0  2021-10
# 2021-11  7.1  2021-11
# 2021-12  7.5  2021-12
#
# [384 rows x 2 columns]

# %% [markdown]
# ## Durable Goods

# %%
#Open and read Durable Goods quarterly dataset
durable_goods = pd.read_csv('C:\\Users\\Nisa\\Documents\\durable_goods (quarterly).csv')

# %%
durable_goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Quarterly  127 non-null    object
#  1   Date       127 non-null    object
#  2   Total      127 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %%
durable_goods.head()
# Out:
#   Quarterly      Date  Total
# 0   1990 Q1  1-Jan-90  11792
# 1   1990 Q2  1-Apr-90  11433
# 2   1990 Q3  1-Jul-90  11028
# 3   1990 Q4  1-Oct-90  11149
# 4   1991 Q1  1-Jan-91  11074

# %%
durable_goods['Date'] = pd.to_datetime(durable_goods['Date']).dt.to_period('M')

# %%
durable_goods_new=durable_goods.set_index('Date').resample('M').interpolate()

# %%
durable_goods_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 379 entries, 1990-01 to 2021-07
# Freq: M
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Quarterly  127 non-null    object
#  1   Total      379 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.9+ KB

# %%
durable_goods_new['Date'] = durable_goods_new.index

# %%
durable_goods_new
# Out:
#         Quarterly         Total     Date
# Date
# 1990-01   1990 Q1  11792.000000  1990-01
# 1990-02       NaN  11672.333333  1990-02
# 1990-03       NaN  11552.666667  1990-03
# 1990-04   1990 Q2  11433.000000  1990-04
# 1990-05       NaN  11298.000000  1990-05
# ...           ...           ...      ...
# 2021-03       NaN  36150.666667  2021-03
# 2021-04   2021 Q2  38245.000000  2021-04
# 2021-05       NaN  38015.333333  2021-05
# 2021-06       NaN  37785.666667  2021-06
# 2021-07   2021 Q3  37556.000000  2021-07
#
# [379 rows x 3 columns]

# %% [markdown]
# ## GDP

# %%
#Open and read Average Earning Index Quarterly dataset
gdp = pd.read_csv('C:\\Users\\Nisa\\Documents\\gdp (quarterly).csv')

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    127 non-null    object
#  1   %       127 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
gdp.head()
# Out:
#        Date    %
# 0  1-Jan-90  0.6
# 1  1-Apr-90  0.5
# 2  1-Jul-90 -1.1
# 3  1-Oct-90 -0.4
# 4  1-Jan-91 -0.3

# %%
#Convert to period
gdp['Date'] = pd.to_datetime(gdp['Date']).dt.to_period('M')

# %%
# set Date as index and resample
gdp_new=gdp.set_index('Date').resample('M').interpolate()

# %%
gdp_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 386 entries, 1990-01 to 2022-02
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   %       386 non-null    float64
# dtypes: float64(1)
# memory usage: 6.0 KB

# %%
gdp_new['Date'] = gdp_new.index

# %%
gdp_new
# Out:
#                 %     Date
# Date
# 1990-01  0.600000  1990-01
# 1990-02  0.566667  1990-02
# 1990-03  0.533333  1990-03
# 1990-04  0.500000  1990-04
# 1990-05 -0.033333  1990-05
# ...           ...      ...
# 2021-10  1.128571  2021-10
# 2021-11  1.071429  2021-11
# 2021-12  1.014286  2021-12
# 2022-01  0.957143  2022-01
# 2022-02  0.900000  2022-02
#
# [386 rows x 2 columns]

# %% [markdown]
# ## House Equity Withdrawal

# %%
house_equity_withdrawal = pd.read_csv('C:\\Users\\Nisa\\Documents\\house_equity_withdrawal (quarterly).csv')

# %%
house_equity_withdrawal.head()
# Out:
#         Date  Changes
# 0  31-Mar-90     1848
# 1  30-Jun-90     2671
# 2  30-Sep-90     2633
# 3  31-Dec-90     2728
# 4  31-Mar-91     1772

# %%
house_equity_withdrawal['Date'] = pd.to_datetime(house_equity_withdrawal['Date']).dt.to_period('M')

# %%
# set Date as index and resample
house_eq_wid_new = house_equity_withdrawal.set_index('Date').resample('M').interpolate()

# %%
house_eq_wid_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 379 entries, 1990-03 to 2021-09
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Changes  379 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
house_eq_wid_new['Date'] = house_eq_wid_new.index

# %%
house_eq_wid_new
# Out:
#              Changes     Date
# Date
# 1990-03  1848.000000  1990-03
# 1990-04  2122.333333  1990-04
# 1990-05  2396.666667  1990-05
# 1990-06  2671.000000  1990-06
# 1990-07  2658.333333  1990-07
# ...              ...      ...
# 2021-05  4977.666667  2021-05
# 2021-06  5058.000000  2021-06
# 2021-07  1455.000000  2021-07
# 2021-08 -2148.000000  2021-08
# 2021-09 -5751.000000  2021-09
#
# [379 rows x 2 columns]

# %% [markdown]
# ## Household Savings Ratio

# %%
household_savings_ratio = pd.read_csv('C:\\Users\\Nisa\\Documents\\household_savings_ratio (quarterly).csv')

# %%
household_savings_ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Quarters  126 non-null    object
#  1   Date      126 non-null    object
#  2   Percent   126 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.1+ KB

# %%
household_savings_ratio.head()
# Out:
#   Quarters      Date  Percent
# 0  1990 Q1  1-Jan-90     10.8
# 1  1990 Q2  1-Apr-90      9.0
# 2  1990 Q3  1-Jul-90     10.2
# 3  1990 Q4  1-Oct-90     11.5
# 4  1991 Q1  1-Jan-91     12.1

# %%
# convert to period
household_savings_ratio['Date'] = pd.to_datetime(household_savings_ratio['Date']).dt.to_period('M')

# %%
# set Date as index and resample
household_savings_ratio_new=household_savings_ratio.set_index('Date').resample('M').interpolate()

# %%
household_savings_ratio_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 376 entries, 1990-01 to 2021-04
# Freq: M
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Quarters  126 non-null    object
#  1   Percent   376 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.8+ KB

# %%
household_savings_ratio_new['Date'] = household_savings_ratio_new.index

# %%
household_savings_ratio_new
# Out:
#         Quarters    Percent     Date
# Date
# 1990-01  1990 Q1  10.800000  1990-01
# 1990-02      NaN  10.200000  1990-02
# 1990-03      NaN   9.600000  1990-03
# 1990-04  1990 Q2   9.000000  1990-04
# 1990-05      NaN   9.400000  1990-05
# ...          ...        ...      ...
# 2020-12      NaN  16.833333  2020-12
# 2021-01  2021 Q1  18.400000  2021-01
# 2021-02      NaN  16.166667  2021-02
# 2021-03      NaN  13.933333  2021-03
# 2021-04  2021 Q2  11.700000  2021-04
#
# [376 rows x 3 columns]

# %% [markdown]
# ## Bank Rate

# %%
bankrate = pd.read_csv('C:\\Users\\Nisa\\Documents\\bankrate (quarterly).csv')

# %%
bankrate.head()
# Out:
#         Date   Rate
# 0   8-Oct-90  13.88
# 1  13-Feb-91  13.38
# 2  22-Mar-91  12.38
# 3  12-Apr-91  11.88
# 4  24-May-91  11.38

# %%
bankrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    73 non-null     object
#  1   Rate    73 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.3+ KB

# %%
# convert to period
bankrate['Date'] = pd.to_datetime(bankrate['Date']).dt.to_period('M')

# %%
#set Date as index and resample
bankrate_new = bankrate.set_index('Date').resample('M').interpolate()

# %%
bankrate_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 375 entries, 1990-10 to 2021-12
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rate    375 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
bankrate_new['Date'] = bankrate_new.index

# %%
bankrate_new
# Out:
#               Rate     Date
# Date
# 1990-10  13.880000  1990-10
# 1990-11  13.755000  1990-11
# 1990-12  13.630000  1990-12
# 1991-01  13.505000  1991-01
# 1991-02  13.380000  1991-02
# ...            ...      ...
# 2021-08   0.221429  2021-08
# 2021-09   0.228571  2021-09
# 2021-10   0.235714  2021-10
# 2021-11   0.242857  2021-11
# 2021-12   0.250000  2021-12
#
# [375 rows x 2 columns]

# %% [markdown]
# ## Claimant Count

# %%
claimant_count = pd.read_csv('C:\\Users\\Nisa\\Documents\\claimant count (monthly).csv')

# %%
claimant_count.head()
# Out:
#        Date  Rate
# 0  1990 Jan   5.6
# 1  1990 Feb   5.6
# 2  1990 Mar   5.5
# 3  1990 Apr   5.4
# 4  1990 May   5.2

# %%
claimant_count['Date'] = pd.to_datetime(claimant_count['Date']).dt.to_period('M')

# %%
# set Date as index and resample
claimant_count_new=claimant_count.set_index('Date').resample('M').interpolate()

# %%
claimant_count_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 382 entries, 1990-01 to 2021-10
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rate    382 non-null    float64
# dtypes: float64(1)
# memory usage: 6.0 KB

# %%
claimant_count_new['Date'] = claimant_count_new.index

# %%
claimant_count_new
# Out:
#          Rate     Date
# Date
# 1990-01   5.6  1990-01
# 1990-02   5.6  1990-02
# 1990-03   5.5  1990-03
# 1990-04   5.4  1990-04
# 1990-05   5.2  1990-05
# ...       ...      ...
# 2021-06   5.7  2021-06
# 2021-07   5.5  2021-07
# 2021-08   5.3  2021-08
# 2021-09   5.0  2021-09
# 2021-10   5.0  2021-10
#
# [382 rows x 2 columns]

# %% [markdown]
# ## House Price Index

# %%
houseprice_index = pd.read_csv('C:\\Users\\Nisa\\Documents\\housepriceindex (monthly).csv')

# %%
houseprice_index.head()
# Out:
#        Date  Index
# 0  1-Jan-90  30.55
# 1  1-Feb-90  30.55
# 2  1-Mar-90  30.55
# 3  1-Apr-90  30.28
# 4  1-May-90  30.28

# %%
houseprice_index['Date'] = pd.to_datetime(houseprice_index['Date']).dt.to_period('M')

# %%
# set Date as index and resample
houseprice_index_new=houseprice_index.set_index('Date').resample('M').interpolate()

# %%
houseprice_index_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 376 entries, 1990-01 to 2021-04
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   376 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
houseprice_index_new['Date'] = houseprice_index_new.index

# %%
houseprice_index_new
# Out:
#           Index     Date
# Date
# 1990-01   30.55  1990-01
# 1990-02   30.55  1990-02
# 1990-03   30.55  1990-03
# 1990-04   30.28  1990-04
# 1990-05   30.28  1990-05
# ...         ...      ...
# 2020-12  130.06  2020-12
# 2021-01  130.96  2021-01
# 2021-02  130.90  2021-02
# 2021-03  133.05  2021-03
# 2021-04  131.45  2021-04
#
# [376 rows x 2 columns]

# %% [markdown]
# ## Final Data

# %%
#functools module is for functions that work on other functions
#reduce function accepts a function and sequence and returns a single value calculated
#reduce is moved to functools module, hence the code

from functools import reduce

# %%
#this is to reset the index of each dataframe
#drop: do not try to insert index into dataframe columns, this resets the index to the default integer index
#inplace: modify the dataFrame in place (do not create a new object)

concatenate_AEI.reset_index(drop=True, inplace=True)
gdp_new.reset_index(drop=True, inplace=True)
durable_goods_new.reset_index(drop=True, inplace=True)
house_eq_wid_new.reset_index(drop=True, inplace=True)
household_savings_ratio_new.reset_index(drop=True, inplace=True)
bankrate_new.reset_index(drop=True, inplace= True)
claimant_count_new.reset_index(drop=True, inplace= True)
retail_price_index_new.reset_index(drop=True, inplace=True)
houseprice_index_new.reset_index(drop = True, inplace = True)

# %%
#delete unused columns for the dataset

durablegoods_new=durable_goods_new.drop(columns={'Quarterly'})
householdSavingsRatio_new=household_savings_ratio_new.drop(columns={'Quarters'})

# %%
#rename columns for the merge dataset

house_eq_wid_new=house_eq_wid_new.rename(columns={"Changes": "House Equity Withdrawal Changes"})
gdp_new=gdp_new.rename(columns={"%": "GDP Percent"})
concatenate_AEI=concatenate_AEI.rename(columns={"Index": "AEI Index"})
bankrate_new=bankrate_new.rename(columns={"Rate": "Bank Rate Value"})
durablegoods_new=durablegoods_new.rename(columns={"Total": "Durable Goods Total"})
householdSavingsRatio_new=householdSavingsRatio_new.rename(columns={"Percent": "Household Savings Ratio Percent"})
claimant_count_new=claimant_count_new.rename(columns={"Rate": "Claimant Count Rate"})
retail_price_index_new= retail_price_index_new.rename(columns={"%": "RPI Percent"})
houseprice_index_new= houseprice_index_new.rename(columns={"Index": "House Price Index"})

# %%
concatenate_AEI.head()
# Out:
#    AEI Index     Date
# 0  62.000000  1990-01
# 1  62.566667  1990-02
# 2  63.133333  1990-03
# 3  63.700000  1990-04
# 4  64.000000  1990-05

# %%
durablegoods_new.head()
# Out:
#    Durable Goods Total     Date
# 0         11792.000000  1990-01
# 1         11672.333333  1990-02
# 2         11552.666667  1990-03
# 3         11433.000000  1990-04
# 4         11298.000000  1990-05

# %%
gdp_new.head()
# Out:
#    GDP Percent     Date
# 0     0.600000  1990-01
# 1     0.566667  1990-02
# 2     0.533333  1990-03
# 3     0.500000  1990-04
# 4    -0.033333  1990-05

# %%
house_eq_wid_new.head()
# Out:
#    House Equity Withdrawal Changes     Date
# 0                      1848.000000  1990-03
# 1                      2122.333333  1990-04
# 2                      2396.666667  1990-05
# 3                      2671.000000  1990-06
# 4                      2658.333333  1990-07

# %%
householdSavingsRatio_new.head()
# Out:
#    Household Savings Ratio Percent     Date
# 0                             10.8  1990-01
# 1                             10.2  1990-02
# 2                              9.6  1990-03
# 3                              9.0  1990-04
# 4                              9.4  1990-05

# %%
bankrate_new.head()
# Out:
#    Bank Rate Value     Date
# 0           13.880  1990-10
# 1           13.755  1990-11
# 2           13.630  1990-12
# 3           13.505  1991-01
# 4           13.380  1991-02

# %%
claimant_count_new.head()
# Out:
#    Claimant Count Rate     Date
# 0                  5.6  1990-01
# 1                  5.6  1990-02
# 2                  5.5  1990-03
# 3                  5.4  1990-04
# 4                  5.2  1990-05

# %%
houseprice_index_new.head()
# Out:
#    House Price Index     Date
# 0              30.55  1990-01
# 1              30.55  1990-02
# 2              30.55  1990-03
# 3              30.28  1990-04
# 4              30.28  1990-05

# %%
#This is to merge the data sets. 
#on: is column or index level anmes to join on
#how, outer: type of merge to be performed; use union of keys from data, sort keys lexicographically (dictionary order)


merge_data = reduce(lambda x,y: pd.merge(x,y, on= 'Date', how= 'outer'), 
                    [gdp_new, concatenate_AEI, house_eq_wid_new, durablegoods_new, householdSavingsRatio_new, bankrate_new, 
                     claimant_count_new, retail_price_index_new, houseprice_index_new])

# %%
merge_data = merge_data.set_index('Date')

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 376 entries, 1990-01 to 2021-04
# Freq: M
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   GDP Percent                      376 non-null    float64
#  1   AEI Index                        376 non-null    float64
#  2   House Equity Withdrawal Changes  376 non-null    float64
#  3   Durable Goods Total              376 non-null    float64
#  4   Household Savings Ratio Percent  376 non-null    float64
#  5   Bank Rate Value                  376 non-null    float64
#  6   Claimant Count Rate              376 non-null    float64
#  7   RPI Percent                      376 non-null    float64
#  8   House Price Index                376 non-null    float64
# dtypes: float64(9)
# memory usage: 29.4 KB

# %%
#Fill NA/NaN values using method
#bfill: use next valid observation to fill gap

merge_data = merge_data.fillna(method ='bfill')

# %%
#eleminate rows where there are any missing elements in the data
merge_data = merge_data.dropna()

# %%
file_name = 'MergeData1.csv'

# saving the excel
merge_data.to_csv(file_name)

# %% [markdown]
# ## Correlation Analysis

# %%
#import all necessary libraries that will be used

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid') #this is to set a grid on the plot graph
sns.set_palette('Set2') #set the colour palette of the plots

# %%
dataTSF = pd.read_csv('C:\\Users\\Nisa\\Nisa Individual Project\\MergeData1.csv')

# %%
dataTSF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             376 non-null    object
#  1   GDP Percent                      376 non-null    float64
#  2   AEI Index                        376 non-null    float64
#  3   House Equity Withdrawal Changes  376 non-null    float64
#  4   Durable Goods Total              376 non-null    float64
#  5   Household Savings Ratio Percent  376 non-null    float64
#  6   Bank Rate Value                  376 non-null    float64
#  7   Claimant Count Rate              376 non-null    float64
#  8   RPI Percent                      376 non-null    float64
#  9   House Price Index                376 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 29.5+ KB

# %% [markdown]
# ## Heatmap

# %%
#create a heatmap using the data frame

plt.figure(figsize=(12,8))
sns.heatmap(dataTSF.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(data = dataTSF, x='AEI Index', y='House Price Index', marker ='D')
# Out:
# <AxesSubplot:xlabel='AEI Index', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='Household Savings Ratio Percent', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='Household Savings Ratio Percent', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='House Equity Withdrawal Changes', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='House Equity Withdrawal Changes', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='Bank Rate Value', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='Bank Rate Value', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='Claimant Count Rate', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='Claimant Count Rate', ylabel='House Price Index'>

# %%
sns.scatterplot(data= dataTSF, x = 'RPI Percent', y= 'House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='RPI Percent', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='GDP Percent', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='GDP Percent', ylabel='House Price Index'>

# %%
sns.scatterplot(data = dataTSF, x='Durable Goods Total', y='House Price Index', marker = 'D')
# Out:
# <AxesSubplot:xlabel='Durable Goods Total', ylabel='House Price Index'>

# %% [markdown]
# **Plotting data using pairplot**

# %%
#using pairplot we'll visualize the data for correlation

sns.pairplot(dataTSF,
            x_vars=['Bank Rate Value', 'GDP Percent', 'Claimant Count Rate', 'Durable Goods Total', 'RPI Percent',
                   'Household Savings Ratio Percent', 'House Equity Withdrawal Changes', 'AEI Index'],
            y_vars='House Price Index')

# %% [markdown]
# ## Regression Analysis

# %%
#import necessary libraries
import numpy as np
import pandas as pd

#supress warnings
import warnings
warnings.filterwarnings('ignore')

#read csv file
regDataTSF = pd.read_csv("MergeData1.csv")
regDataTSF.head()
# Out:
#       Date  GDP Percent  AEI Index  House Equity Withdrawal Changes  \
# 0  1990-01     0.600000  62.000000                      1848.000000
# 1  1990-02     0.566667  62.566667                      1848.000000
# 2  1990-03     0.533333  63.133333                      1848.000000
# 3  1990-04     0.500000  63.700000                      2122.333333
# 4  1990-05    -0.033333  64.000000                      2396.666667
#
#    Durable Goods Total  Household Savings Ratio Percent  Bank Rate Value  \
# 0         11792.000000                             10.8            13.88
# 1         11672.333333                             10.2            13.88
# 2         11552.666667                              9.6            13.88
# 3         11433.000000                              9.0            13.88
# 4         11298.000000                              9.4            13.88
#
#    Claimant Count Rate  RPI Percent  House Price Index
# 0                  5.6          7.7              30.55
# ...

# %% [markdown]
# **Understanding The Data**

# %%
regDataTSF.shape
# Out:
# (376, 10)

# %%
regDataTSF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             376 non-null    object
#  1   GDP Percent                      376 non-null    float64
#  2   AEI Index                        376 non-null    float64
#  3   House Equity Withdrawal Changes  376 non-null    float64
#  4   Durable Goods Total              376 non-null    float64
#  5   Household Savings Ratio Percent  376 non-null    float64
#  6   Bank Rate Value                  376 non-null    float64
#  7   Claimant Count Rate              376 non-null    float64
#  8   RPI Percent                      376 non-null    float64
#  9   House Price Index                376 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 29.5+ KB

# %%
regDataTSF.describe()
# Out:
#        GDP Percent   AEI Index  House Equity Withdrawal Changes  \
# count   376.000000  376.000000                       376.000000
# mean      0.442154  120.647872                      -613.725177
# std       1.916650   34.505526                      7610.497016
# min     -19.600000   62.000000                    -11290.000000
# 25%       0.300000   88.743750                     -8124.000000
# 50%       0.533333  123.500000                      -877.666667
# 75%       0.700000  148.750000                      3045.750000
# max      17.400000  197.900000                     17347.000000
#
#        Durable Goods Total  Household Savings Ratio Percent  Bank Rate Value  \
# count           376.000000                       376.000000       376.000000
# mean          22538.776596                         9.160372         3.957620
# std            7090.067491                         2.839588         3.508750
# min           10949.000000                         3.600000         0.100000
# ...

# %% [markdown]
# # Multiple Linear Regression

# %%
#defining x and y

x = regDataTSF.drop(['Date', 'House Price Index'], axis = 1).values
y = regDataTSF['House Price Index'].values

# %%
print(x)
# Out:
# [[6.00000000e-01 6.20000000e+01 1.84800000e+03 ... 1.38800000e+01
#   5.60000000e+00 7.70000000e+00]
#  [5.66666667e-01 6.25666667e+01 1.84800000e+03 ... 1.38800000e+01
#   5.60000000e+00 7.50000000e+00]
#  [5.33333333e-01 6.31333333e+01 1.84800000e+03 ... 1.38800000e+01
#   5.50000000e+00 8.10000000e+00]
#  ...
#  [9.00000000e-01 1.84500000e+02 3.02300000e+03 ... 1.78571429e-01
#   6.60000000e+00 1.40000000e+00]
#  [3.20000000e+00 1.97900000e+02 4.81700000e+03 ... 1.85714286e-01
#   6.60000000e+00 1.50000000e+00]
#  [5.50000000e+00 1.84000000e+02 4.89733333e+03 ... 1.92857143e-01
#   6.50000000e+00 2.90000000e+00]]

# %%
print(y)
# Out:
# [ 30.55  30.55  30.55  30.28  30.28  30.28  30.83  30.83  30.83  30.37
#   30.37  30.37  29.94  29.94  29.94  29.82  29.82  29.82  30.4   30.4
#   30.4   30.12  30.12  30.12  29.64  29.64  29.64  28.93  28.93  28.93
#   29.02  29.02  29.02  27.91  27.91  27.91  28.05  28.05  28.05  28.28
#   28.28  28.28  28.88  28.88  28.88  28.34  28.34  28.34  28.65  28.65
#   28.65  29.05  29.05  29.05  29.53  29.53  29.53  29.33  29.33  29.33
#   29.08  29.08  29.08  29.39  29.39  29.39  29.64  29.64  29.64  29.25
#   29.25  29.25  29.67  29.67  29.67  29.7   29.7   29.7   30.87  30.87
#   30.87  31.41  31.41  31.41  31.84  31.84  31.84  32.49  32.49  32.49
#   34.14  34.14  34.14  33.88  33.88  33.88  34.74  34.74  34.74  36.59
#   36.59  36.59  38.18  38.18  38.18  38.01  38.01  38.01  38.24  38.24
#   38.24  39.86  39.86  39.86  42.19  42.19  42.19  43.27  43.27  43.27
#   44.38  44.38  44.38  46.8   46.8   46.8   47.68  47.68  47.68  49.1
# ...

# %%
#spliting the dataset in training set and test set

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (263, 8)
# (113, 8)
# (263,)
# (113,)

# %%
#train the model on the training set

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#predict the test set results

y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [ 52.41934206  96.65624844 110.32209745 125.81693755  91.94998503
#   44.13385757  87.39545111  62.67780839  33.84184677  27.48054215
#   99.95040815  72.50039077  32.12841663  85.55924729 125.07558609
#   96.97253881  26.8918716   77.58976606 127.60019808 105.14789282
#   63.4252608   23.07077699  86.25956395  83.41575966  86.79844807
#   34.29299427  85.63006733  98.50584638  29.83086666  23.90248741
#   95.55374483  40.18237437  31.52097433  80.99135927  57.31276209
#   90.41229274  72.50527967  60.96687249  31.82433641  25.65646324
#   33.99354991 102.40359825 106.95050096 147.34548636  23.63211841
#   25.16020559 103.05588265 135.14740889  29.29808132  32.54704914
#   71.08831268  32.39425235  80.82945152  77.93926829  29.99886335
#   82.00256769  41.67994465  24.19903996  42.41947815  59.7465249
#   77.97687152 132.83425159  87.64376104  83.29181373  85.81742661
#   31.42030235  27.26094024  85.75628628 105.9341718   72.39008198
# ...

# %%
regressor.predict([[0.600000, 62.000000, 1848.000000, 11792.000000, 10.8, 13.88, 5.6]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-700-0fd8e2a4d45f> in <module>
# ----> 1 regressor.predict([[0.600000, 62.000000, 1848.000000, 11792.000000, 10.8, 13.88, 5.6]])
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#     223
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
#evaluate the model

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9708557317514921

# %%
#plot the results

import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted')

# %%
#predicted values

pred_y_df = pd.DataFrame({'Actual Value':y_test, 'Predicted value':y_pred, 'Difference': y_test-y_pred})
pred_y_df[0:20]
# Out:
#     Actual Value  Predicted value  Difference
# 0          44.38        52.419342   -8.039342
# 1         100.62        96.656248    3.963752
# 2         107.81       110.322097   -2.512097
# 3         124.14       125.816938   -1.676938
# 4          92.71        91.949985    0.760015
# 5          38.18        44.133858   -5.953858
# 6          88.64        87.395451    1.244549
# 7          53.06        62.677808   -9.617808
# 8          29.70        33.841847   -4.141847
# 9          29.05        27.480542    1.569458
# 10        100.09        99.950408    0.139592
# 11         74.55        72.500391    2.049609
# 12         29.08        32.128417   -3.048417
# 13         88.76        85.559247    3.200753
# 14        122.49       125.075586   -2.585586
# 15         96.60        96.972539   -0.372539
# 16         29.53        26.891872    2.638128
# 17         71.84        77.589766   -5.749766
# 18        120.66       127.600198   -6.940198
# ...

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# **Durable Goods Total vs AEI Index**

# %%
#import necessary libraries
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
#creating X and Y

x = regDataTSF['Durable Goods Total']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
#take a look at the train dataset
x_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  15.473072
# Durable Goods Total     0.004666
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     2824.
# Date:                Fri, 06 May 2022   Prob (F-statistic):          5.44e-142
# Time:                        10:25:07   Log-Likelihood:                -977.53
# No. Observations:                 263   AIC:                             1959.
# Df Residuals:                     261   BIC:                             1966.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
#visualizing the regression line

plt.scatter(x_train, y_train)
plt.plot(x_train, 15.4731 + 0.0047 * x_train, 'r')
plt.show()

# %% [markdown]
# **GDP Percent vs AEI Index**

# %%
x = regDataTSF['GDP Percent']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          121.511424
# GDP Percent     -0.865143
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6849
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.409
# Time:                        10:25:09   Log-Likelihood:                -1302.0
# No. Observations:                 263   AIC:                             2608.
# Df Residuals:                     261   BIC:                             2615.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         121.5114      2.170     55.987      0.000     117.238     125.785
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 121.5114 + -0.8651 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Equity Withdrawal vs  AEI Index**

# %%
x = regDataTSF['House Equity Withdrawal Changes']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              119.202783
# House Equity Withdrawal Changes     -0.002055
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.197
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     63.96
# Date:                Fri, 06 May 2022   Prob (F-statistic):           4.14e-14
# Time:                        10:25:12   Log-Likelihood:                -1273.5
# No. Observations:                 263   AIC:                             2551.
# Df Residuals:                     261   BIC:                             2558.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 191.2028 + -0.0021 * x_train, 'r')
plt.show()

# %% [markdown]
# **Household Savings Ratio Percent vs AEI Index**

# %%
x = regDataTSF['Household Savings Ratio Percent']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              155.248545
# Household Savings Ratio Percent     -3.755344
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     27.02
# Date:                Fri, 06 May 2022   Prob (F-statistic):           4.06e-07
# Time:                        10:25:14   Log-Likelihood:                -1289.4
# No. Observations:                 263   AIC:                             2583.
# Df Residuals:                     261   BIC:                             2590.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 155.2485 + -3.7553 * x_train, 'r')
plt.show()

# %% [markdown]
# **Bank Rate vs AEI Index**

# %%
x = regDataTSF['Bank Rate Value']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const              155.269649
# Bank Rate Value     -8.794576
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     842.9
# Date:                Fri, 06 May 2022   Prob (F-statistic):           1.05e-83
# Time:                        10:25:17   Log-Likelihood:                -1112.7
# No. Observations:                 263   AIC:                             2229.
# Df Residuals:                     261   BIC:                             2236.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 155.2696 + -8.7946 * x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs AEI Index**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  165.612959
# Claimant Count Rate     -9.894637
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     189.0
# Date:                Fri, 06 May 2022   Prob (F-statistic):           1.03e-32
# Time:                        10:25:20   Log-Likelihood:                -1230.7
# No. Observations:                 263   AIC:                             2465.
# Df Residuals:                     261   BIC:                             2473.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 165.6130 + -9.8946 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs AEI Index**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          137.681880
# RPI Percent     -5.469996
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     21.09
# Date:                Fri, 06 May 2022   Prob (F-statistic):           6.83e-06
# Time:                        10:25:21   Log-Likelihood:                -1292.1
# No. Observations:                 263   AIC:                             2588.
# Df Residuals:                     261   BIC:                             2595.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         137.6819      4.144     33.223      0.000     129.522     145.842
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 137.6819 + -5.4700 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs AEI Index**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['AEI Index']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    116.000
# 35      73.275
# 300    151.900
# 39      73.400
# 363    168.900
#         ...
# 343    163.500
# 359    173.700
# 323    158.700
# 280    147.600
# 8       66.300
# Name: AEI Index, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                48.259471
# House Price Index     1.011598
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AEI Index   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     4665.
# Date:                Fri, 06 May 2022   Prob (F-statistic):          1.59e-168
# Time:                        10:25:23   Log-Likelihood:                -915.98
# No. Observations:                 263   AIC:                             1836.
# Df Residuals:                     261   BIC:                             1843.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 48.259471 + 1.011598 * x_train, 'r')
plt.show()

# %% [markdown]
# **GDP Percent vs Durable Goods**

# %%
x = regDataTSF['GDP Percent']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          22535.227182
# GDP Percent      225.509697
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.004
# Model:                             OLS   Adj. R-squared:                  0.000
# Method:                  Least Squares   F-statistic:                     1.109
# Date:                 Fri, 06 May 2022   Prob (F-statistic):              0.293
# Time:                         10:25:26   Log-Likelihood:                -2701.8
# No. Observations:                  263   AIC:                             5408.
# Df Residuals:                      261   BIC:                             5415.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 22535.227182 + 225.509697 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Equity Withdrawal vs Durable Goods**

# %%
x = regDataTSF['House Equity Withdrawal Changes']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              22351.910783
# House Equity Withdrawal Changes       -0.310360
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.107
# Model:                             OLS   Adj. R-squared:                  0.103
# Method:                  Least Squares   F-statistic:                     31.21
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           5.81e-08
# Time:                         10:25:28   Log-Likelihood:                -2687.5
# No. Observations:                  263   AIC:                             5379.
# Df Residuals:                      261   BIC:                             5386.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 22351.910783 + -0.3104 * x_train, 'r')
plt.show()

# %% [markdown]
# **Household Savings Ratio vs Durable Goods**

# %%
x = regDataTSF['Household Savings Ratio Percent']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              32017.661387
# Household Savings Ratio Percent    -1031.566494
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.168
# Model:                             OLS   Adj. R-squared:                  0.165
# Method:                  Least Squares   F-statistic:                     52.84
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           4.20e-12
# Time:                         10:25:30   Log-Likelihood:                -2678.1
# No. Observations:                  263   AIC:                             5360.
# Df Residuals:                      261   BIC:                             5367.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 32017.661387 + -1031.566494 * x_train, 'r')
plt.show()

# %% [markdown]
# **Bank Rate vs Durable Goods**

# %%
x = regDataTSF['Bank Rate Value']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const              29301.292219
# Bank Rate Value    -1714.979538
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.691
# Model:                             OLS   Adj. R-squared:                  0.689
# Method:                  Least Squares   F-statistic:                     582.5
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           1.96e-68
# Time:                         10:25:32   Log-Likelihood:                -2548.1
# No. Observations:                  263   AIC:                             5100.
# Df Residuals:                      261   BIC:                             5107.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  29301.292219 + -1714.979538 * x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs Durable Goods**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  32758.598950
# Claimant Count Rate    -2249.729076
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.516
# Model:                             OLS   Adj. R-squared:                  0.514
# Method:                  Least Squares   F-statistic:                     278.6
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           4.66e-43
# Time:                         10:25:34   Log-Likelihood:                -2606.8
# No. Observations:                  263   AIC:                             5218.
# Df Residuals:                      261   BIC:                             5225.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  32758.598950 + -2249.729076 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs Durable Goods**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          26733.580538
# RPI Percent    -1351.185594
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.108
# Model:                             OLS   Adj. R-squared:                  0.105
# Method:                  Least Squares   F-statistic:                     31.76
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           4.51e-08
# Time:                         10:25:36   Log-Likelihood:                -2687.2
# No. Observations:                  263   AIC:                             5378.
# Df Residuals:                      261   BIC:                             5386.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  26733.580538 + -1351.185594 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs Durable Goods**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['Durable Goods Total']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    23338.333333
# 35     11954.000000
# 300    28763.000000
# 39     11840.000000
# 363    25880.000000
#            ...
# 343    33334.333333
# 359    32754.333333
# 323    32122.666667
# 280    26304.333333
# 8      11108.666667
# Name: Durable Goods Total, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                7914.341621
# House Price Index     204.479801
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Durable Goods Total   R-squared:                       0.920
# Model:                             OLS   Adj. R-squared:                  0.920
# Method:                  Least Squares   F-statistic:                     3012.
# Date:                 Fri, 06 May 2022   Prob (F-statistic):          2.39e-145
# Time:                         10:25:38   Log-Likelihood:                -2369.8
# No. Observations:                  263   AIC:                             4744.
# Df Residuals:                      261   BIC:                             4751.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  7914.341621 + 204.479801 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Equity Withdrawal vs GDP Percent**

# %%
x = regDataTSF['House Equity Withdrawal Changes']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              0.476139
# House Equity Withdrawal Changes    0.000013
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5594
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.455
# Time:                        10:25:40   Log-Likelihood:                -558.28
# No. Observations:                 263   AIC:                             1121.
# Df Residuals:                     261   BIC:                             1128.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.476139 + 0.000013 * x_train, 'r')
plt.show()

# %% [markdown]
# **Household Savings Ratio vs GDP Percent**

# %%
x = regDataTSF['Household Savings Ratio Percent']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              1.526951
# Household Savings Ratio Percent   -0.116884
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     6.965
# Date:                Fri, 06 May 2022   Prob (F-statistic):            0.00881
# Time:                        10:25:42   Log-Likelihood:                -555.09
# No. Observations:                 263   AIC:                             1114.
# Df Residuals:                     261   BIC:                             1121.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  1.526951 + -0.116884 * x_train, 'r')
plt.show()

# %% [markdown]
# **Bank Rate vs GDP Percent**

# %%
x = regDataTSF['Bank Rate Value']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const              0.465624
# Bank Rate Value   -0.000319
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                 7.494e-05
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.993
# Time:                        10:25:44   Log-Likelihood:                -558.56
# No. Observations:                 263   AIC:                             1121.
# Df Residuals:                     261   BIC:                             1128.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.465624 + -0.000319 * x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs GDP Percent**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  0.108056
# Claimant Count Rate    0.079224
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.025
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.156
# Time:                        10:25:47   Log-Likelihood:                -557.54
# No. Observations:                 263   AIC:                             1119.
# Df Residuals:                     261   BIC:                             1126.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.108056 + 0.079224 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs GDP Percent**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          0.765213
# RPI Percent   -0.099294
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.852
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.175
# Time:                        10:25:49   Log-Likelihood:                -557.63
# No. Observations:                 263   AIC:                             1119.
# Df Residuals:                     261   BIC:                             1126.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.7652      0.254      3.014      0.003       0.265       1.265
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.765213 + -0.099294 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs GDP Percent**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['GDP Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     0.300000
# 35      0.700000
# 300     0.600000
# 39      0.500000
# 363   -19.600000
#          ...
# 343     0.500000
# 359    -1.800000
# 323     0.633333
# 280     0.733333
# 8      -0.633333
# Name: GDP Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                0.714550
# House Price Index   -0.003474
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            GDP Percent   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8362
# Date:                Fri, 06 May 2022   Prob (F-statistic):              0.361
# Time:                        10:25:51   Log-Likelihood:                -558.14
# No. Observations:                 263   AIC:                             1120.
# Df Residuals:                     261   BIC:                             1127.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.714550 + -0.003474 * x_train, 'r')
plt.show()

# %% [markdown]
# **Household Savings Ratio vs House Equity Withdrawal**

# %%
x = regDataTSF['Household Savings Ratio Percent']
y = regDataTSF['House Equity Withdrawal Changes']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                              4132.621735
# Household Savings Ratio Percent    -556.687470
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     House Equity Withdrawal Changes   R-squared:                       0.044
# Model:                                         OLS   Adj. R-squared:                  0.041
# Method:                              Least Squares   F-statistic:                     12.07
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           0.000598
# Time:                                     10:25:54   Log-Likelihood:                -2710.0
# No. Observations:                              263   AIC:                             5424.
# Df Residuals:                                  261   BIC:                             5431.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  4132.621735 + -556.687470 * x_train, 'r')
plt.show()

# %% [markdown]
# **Bank Rate vs House Equity Withdrawal**

# %%
x = regDataTSF['Bank Rate Value']
y = regDataTSF['House Equity Withdrawal Changes']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const             -5487.969812
# Bank Rate Value    1173.954419
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     House Equity Withdrawal Changes   R-squared:                       0.292
# Model:                                         OLS   Adj. R-squared:                  0.289
# Method:                              Least Squares   F-statistic:                     107.5
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           2.52e-21
# Time:                                     10:25:56   Log-Likelihood:                -2670.5
# No. Observations:                              263   AIC:                             5345.
# Df Residuals:                                  261   BIC:                             5352.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  -5487.969812 + 1173.954419 * x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs House Equity Withdrawal**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['House Equity Withdrawal Changes']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                   66.31570
# Claimant Count Rate   -221.08972
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     House Equity Withdrawal Changes   R-squared:                       0.004
# Model:                                         OLS   Adj. R-squared:                  0.001
# Method:                              Least Squares   F-statistic:                     1.179
# Date:                             Fri, 06 May 2022   Prob (F-statistic):              0.279
# Time:                                     10:25:58   Log-Likelihood:                -2715.3
# No. Observations:                              263   AIC:                             5435.
# Df Residuals:                                  261   BIC:                             5442.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  66.31570 + -221.08972 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs House Equity Withdrawal**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['House Equity Withdrawal Changes']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const         -2064.345236
# RPI Percent     375.046181
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     House Equity Withdrawal Changes   R-squared:                       0.008
# Model:                                         OLS   Adj. R-squared:                  0.004
# Method:                              Least Squares   F-statistic:                     1.982
# Date:                             Fri, 06 May 2022   Prob (F-statistic):              0.160
# Time:                                     10:26:00   Log-Likelihood:                -2714.9
# No. Observations:                              263   AIC:                             5434.
# Df Residuals:                                  261   BIC:                             5441.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  -2064.345236 + 375.046181 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs House Equity Withdrawal**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['House Equity Withdrawal Changes']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173    15419.000000
# 35     -1779.000000
# 300    -9697.333333
# 39     -1292.333333
# 363    -7244.000000
#            ...
# 343    -6920.333333
# 359    -4680.000000
# 323    -8936.000000
# 280   -10236.333333
# 8       2633.000000
# Name: House Equity Withdrawal Changes, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                4604.481601
# House Price Index     -76.825199
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     House Equity Withdrawal Changes   R-squared:                       0.117
# Model:                                         OLS   Adj. R-squared:                  0.114
# Method:                              Least Squares   F-statistic:                     34.63
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           1.22e-08
# Time:                                     10:26:02   Log-Likelihood:                -2699.5
# No. Observations:                              263   AIC:                             5403.
# Df Residuals:                                  261   BIC:                             5410.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  4604.481601 + -76.825199 * x_train, 'r')
plt.show()

# %% [markdown]
# **Bank Rate vs Household Savings Ratio**

# %%
x = regDataTSF['Bank Rate Value']
y = regDataTSF['Household Savings Ratio Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const              8.421377
# Bank Rate Value    0.172331
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Household Savings Ratio Percent   R-squared:                       0.044
# Model:                                         OLS   Adj. R-squared:                  0.040
# Method:                              Least Squares   F-statistic:                     12.03
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           0.000611
# Time:                                     10:26:05   Log-Likelihood:                -637.20
# No. Observations:                              263   AIC:                             1278.
# Df Residuals:                                  261   BIC:                             1286.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  8.421377 + 0.172331* x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs Household Savings Ratio**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['Household Savings Ratio Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  4.835895
# Claimant Count Rate    0.946002
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Household Savings Ratio Percent   R-squared:                       0.577
# Model:                                         OLS   Adj. R-squared:                  0.575
# Method:                              Least Squares   F-statistic:                     356.1
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           1.11e-50
# Time:                                     10:26:07   Log-Likelihood:                -529.98
# No. Observations:                              263   AIC:                             1064.
# Df Residuals:                                  261   BIC:                             1071.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  4.835895 + 0.946002 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs Household Savings Ratio**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['Household Savings Ratio Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          8.917995
# RPI Percent    0.057021
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Household Savings Ratio Percent   R-squared:                       0.001
# Model:                                         OLS   Adj. R-squared:                 -0.003
# Method:                              Least Squares   F-statistic:                    0.3191
# Date:                             Fri, 06 May 2022   Prob (F-statistic):              0.573
# Time:                                     10:26:09   Log-Likelihood:                -642.97
# No. Observations:                              263   AIC:                             1290.
# Df Residuals:                                  261   BIC:                             1297.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  8.917995 + 0.057021 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs Househol Savings Ratio Percent**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['Household Savings Ratio Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     6.733333
# 35     13.400000
# 300    10.100000
# 39     14.400000
# 363    23.400000
#          ...
# 343     6.500000
# 359     7.033333
# 323     4.900000
# 280     8.000000
# 8      11.066667
# Name: Household Savings Ratio Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                10.990847
# House Price Index    -0.026385
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Household Savings Ratio Percent   R-squared:                       0.097
# Model:                                         OLS   Adj. R-squared:                  0.093
# Method:                              Least Squares   F-statistic:                     27.99
# Date:                             Fri, 06 May 2022   Prob (F-statistic):           2.59e-07
# Time:                                     10:26:11   Log-Likelihood:                -629.73
# No. Observations:                              263   AIC:                             1263.
# Df Residuals:                                  261   BIC:                             1271.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  10.990847 + -0.026385 * x_train, 'r')
plt.show()

# %% [markdown]
# **Claimant Count vs Bank Rate**

# %%
x = regDataTSF['Claimant Count Rate']
y = regDataTSF['Bank Rate Value']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                  0.713892
# Claimant Count Rate    0.704873
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Bank Rate Value   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     71.86
# Date:                Fri, 06 May 2022   Prob (F-statistic):           1.73e-15
# Time:                        10:26:13   Log-Likelihood:                -663.06
# No. Observations:                 263   AIC:                             1330.
# Df Residuals:                     261   BIC:                             1337.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.713892 + 0.704873 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs Bank Rate**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['Bank Rate Value']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          0.643072
# RPI Percent    1.069803
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Bank Rate Value   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     106.4
# Date:                Fri, 06 May 2022   Prob (F-statistic):           3.76e-21
# Time:                        10:26:15   Log-Likelihood:                -650.06
# No. Observations:                 263   AIC:                             1304.
# Df Residuals:                     261   BIC:                             1311.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.6431      0.361      1.782      0.076      -0.067       1.353
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  0.643072 + 1.069803 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs Bank Rate Value**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['Bank Rate Value']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     4.500000
# 35      6.380000
# 300     0.303371
# 39      5.730000
# 363     0.107143
#          ...
# 343     0.750000
# 359     0.202632
# 323     0.316667
# 280     0.359551
# 8      13.880000
# Name: Bank Rate Value, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                9.892912
# House Price Index   -0.083437
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Bank Rate Value   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     490.3
# Date:                Fri, 06 May 2022   Prob (F-statistic):           7.33e-62
# Time:                        10:26:17   Log-Likelihood:                -556.01
# No. Observations:                 263   AIC:                             1116.
# Df Residuals:                     261   BIC:                             1123.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  9.892912 + -0.083437 * x_train, 'r')
plt.show()

# %% [markdown]
# **RPI Percent vs Claimant Count**

# %%
x = regDataTSF['RPI Percent']
y = regDataTSF['Claimant Count Rate']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const          4.056273
# RPI Percent    0.145708
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Claimant Count Rate   R-squared:                       0.012
# Model:                             OLS   Adj. R-squared:                  0.009
# Method:                  Least Squares   F-statistic:                     3.268
# Date:                 Fri, 06 May 2022   Prob (F-statistic):             0.0718
# Time:                         10:26:20   Log-Likelihood:                -583.78
# No. Observations:                  263   AIC:                             1172.
# Df Residuals:                      261   BIC:                             1179.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  4.056273 + 0.145708 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs Claimant Count**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['Claimant Count Rate']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     2.6
# 35     10.0
# 300     2.5
# 39     10.2
# 363     5.3
#        ...
# 343     2.5
# 359     3.2
# 323     2.1
# 280     4.3
# 8       5.6
# Name: Claimant Count Rate, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                7.774962
# House Price Index   -0.045508
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Claimant Count Rate   R-squared:                       0.447
# Model:                             OLS   Adj. R-squared:                  0.445
# Method:                  Least Squares   F-statistic:                     210.8
# Date:                 Fri, 06 May 2022   Prob (F-statistic):           2.05e-35
# Time:                         10:26:22   Log-Likelihood:                -507.57
# No. Observations:                  263   AIC:                             1019.
# Df Residuals:                      261   BIC:                             1026.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  7.774962 + -0.045508 * x_train, 'r')
plt.show()

# %% [markdown]
# **House Price Index vs RPI Percent**

# %%
x = regDataTSF['House Price Index']
y = regDataTSF['RPI Percent']

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size= 0.7, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
# 173     76.78
# 35      27.91
# 300    100.00
# 39      28.28
# 363    120.80
#         ...
# 343    121.63
# 359    121.57
# 323    113.03
# 280     89.81
# 8       30.83
# Name: House Price Index, Length: 263, dtype: float64

# %%
y_train
# Out:
# 173     3.0
# 35      2.6
# 300     1.1
# 39      1.3
# 363     1.5
#        ...
# 343     3.5
# 359     2.2
# 323     2.5
# 280     3.1
# 8      10.9
# Name: RPI Percent, Length: 263, dtype: float64

# %%
#adding a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# %%
#fitting the regression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
#printing the parameters
lr.params
# Out:
# const                3.789552
# House Price Index   -0.010552
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            RPI Percent   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     11.23
# Date:                Fri, 06 May 2022   Prob (F-statistic):           0.000926
# Time:                        10:26:24   Log-Likelihood:                -508.81
# No. Observations:                 263   AIC:                             1022.
# Df Residuals:                     261   BIC:                             1029.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,  3.789552 + -0.010552 * x_train, 'r')
plt.show()

# %% [markdown]
# ### Based on Comparison study of all Single Linear Regressions, only a few variables that influences the most for the house price market which are:
#
# 1) Average Earning Index
#
# 2) Bank Rate
#
# 3) Durable Goods
#
# 4) HPI Index

# %%
updatedDataTSF = regDataTSF.drop(['GDP Percent', 'House Equity Withdrawal Changes', 'Household Savings Ratio Percent', 
                                  'Claimant Count Rate', 'RPI Percent'], axis = 1)

# %%
file_name = 'updatedDataTSF.csv'

# saving the excel
updatedDataTSF.to_csv(file_name)

# %% [markdown]
# ## Pearson's Correlation Coeficient

# %%
#imported libraries
import numpy as np
import scipy.stats

# %%
#instantiated variables from dataset by columns
GDP_Percent = dataTSF['GDP Percent']
AEI_Index = dataTSF['AEI Index']
HEW_Changes = dataTSF['House Equity Withdrawal Changes']
HSR_Percent = dataTSF['Household Savings Ratio Percent']
DG_Total = dataTSF['Durable Goods Total']
BR_Value = dataTSF['Bank Rate Value']
CC_Rate = dataTSF['Claimant Count Rate']
RPI_Percent = dataTSF['RPI Percent']
HPI_Index = dataTSF['House Price Index']

# %%
correlations = dataTSF.corr()
correlations
# Out:
#                                  GDP Percent  AEI Index  \
# GDP Percent                         1.000000  -0.059859
# AEI Index                          -0.059859   1.000000
# House Equity Withdrawal Changes     0.061206  -0.423238
# Durable Goods Total                 0.065092   0.956582
# Household Savings Ratio Percent    -0.185340  -0.277964
# Bank Rate Value                    -0.005020  -0.873838
# Claimant Count Rate                 0.084919  -0.632401
# RPI Percent                        -0.085687  -0.283491
# House Price Index                  -0.056073   0.973214
#
#                                  House Equity Withdrawal Changes  \
# GDP Percent                                             0.061206
# AEI Index                                              -0.423238
# House Equity Withdrawal Changes                         1.000000
# Durable Goods Total                                    -0.304511
# Household Savings Ratio Percent                        -0.207958
# ...

# %%
correlations["House Price Index"]
# Out:
# GDP Percent                       -0.056073
# AEI Index                          0.973214
# House Equity Withdrawal Changes   -0.320599
# Durable Goods Total                0.960121
# Household Savings Ratio Percent   -0.294632
# Bank Rate Value                   -0.805456
# Claimant Count Rate               -0.658275
# RPI Percent                       -0.207773
# House Price Index                  1.000000
# Name: House Price Index, dtype: float64

# %% [markdown]
# ***These functions return objects that contain two values (x, y):***
#
# ***1. The correlation coeficient (x)***
#
# ***2. The p-value (y)***

# %%
scipy.stats.pearsonr(GDP_Percent, HPI_Index)
# Out:
# (-0.05607272652172899, 0.2781326415594666)

# %%
scipy.stats.pearsonr(RPI_Percent, HPI_Index)
# Out:
# (-0.20777337506633622, 4.910399067425082e-05)

# %%
scipy.stats.pearsonr(DG_Total, HPI_Index)
# Out:
# (0.9601212421126069, 4.249935471331392e-209)

# %%
scipy.stats.pearsonr(HSR_Percent, HPI_Index)
# Out:
# (-0.29463238797283486, 5.749380528641208e-09)

# %%
scipy.stats.pearsonr(BR_Value, HPI_Index)
# Out:
# (-0.8054557179219196, 5.454343467295903e-87)

# %%
scipy.stats.pearsonr(CC_Rate, HPI_Index)
# Out:
# (-0.6582751549106897, 4.6623810364412045e-48)

# %%
scipy.stats.pearsonr(HEW_Changes, HPI_Index)
# Out:
# (-0.3205987870913439, 1.9564680564677413e-10)

# %%
scipy.stats.pearsonr(AEI_Index, HPI_Index)
# Out:
# (0.9732141383732988, 6.964198070492375e-241)

# %% [markdown]
# ***From the result the p-values are less than 0.05 besides GDP Value.
# We can conclude there is a ralation between the other variables against Average Earning Index.***
#
# **Only average earning index and durable goods have a positive relationship while the rest have a negative relationship**

# %% [markdown]
# # Multivariate Time Series with RNN model using LSTM

# %%
#Perform imports and load datasets

import pandas as pd
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pandas import DataFrame, concat
from sklearn.metrics import mean_absolute_error, mean_squared_error
from numpy import mean, concatenate
from math import sqrt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM, Activation, Dropout
from numpy import array, hstack
from tensorflow import keras
import tensorflow as tf

#rnndf = pd.read_csv("MergeData1.csv", index_col=['Date'], infer_datetime_format = True)

rnndf = pd.read_csv("MergeData1.csv")
rnndf = rnndf.drop(['GDP Percent', 'House Equity Withdrawal Changes', 'Household Savings Ratio Percent', 
                                  'Claimant Count Rate', 'RPI Percent'], axis = 1)
train_dates = pd.to_datetime(rnndf['Date'])

cols = list(rnndf)[1:6]
rnndf_training = rnndf[cols].astype(float)
rnndf_training
# Out:
#       AEI Index  Durable Goods Total  Bank Rate Value  House Price Index
# 0     62.000000         11792.000000        13.880000              30.55
# 1     62.566667         11672.333333        13.880000              30.55
# 2     63.133333         11552.666667        13.880000              30.55
# 3     63.700000         11433.000000        13.880000              30.28
# 4     64.000000         11298.000000        13.880000              30.28
# ..          ...                  ...              ...                ...
# 371  183.500000         33239.000000         0.164286             130.06
# 372  183.100000         31962.000000         0.171429             130.96
# 373  184.500000         34056.333333         0.178571             130.90
# 374  197.900000         36150.666667         0.185714             133.05
# 375  184.000000         38245.000000         0.192857             131.45
#
# [376 rows x 4 columns]

# %%
rnndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 376 non-null    object
#  1   AEI Index            376 non-null    float64
#  2   Durable Goods Total  376 non-null    float64
#  3   Bank Rate Value      376 non-null    float64
#  4   House Price Index    376 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 14.8+ KB

# %%
scaler = StandardScaler()
scaler = scaler.fit(rnndf_training)
rnndf_training_scaled = scaler.transform(rnndf_training)

# %%
trainX=[] #training
trainY=[] #prediction

n_future = 1 #number of days we want to predict into the future
n_past = 12 #number of past days we want to use to predict the future

for i in range(n_past, len(rnndf_training_scaled) - n_future + 1):
    trainX.append(rnndf_training_scaled[i - n_past:i, 0:rnndf_training.shape[1]])
    trainY.append(rnndf_training_scaled[i + n_future -1:i + n_future, 0])
    
#converting list into array
trainX, trainY = np.array(trainX), np.array(trainY)

#trainX1 = tf.convert_to_tensor(trainX, dtype = tf.float32)
#trainY1 = tf.convert_to_tensor(trainY, dtype = tf.float32)

print('trainX shape == {}'.format(trainX.shape))
print('trainY shape == {}'.format(trainY.shape))
# Out:
# trainX shape == (364, 12, 4)
# trainY shape == (364, 1)

# %%
#pip install -U numpy==1.18.5

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences = True))
model.add(LSTM(32, activation = 'relu', return_sequences = False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer = 'adam', loss = 'mse')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_6 (LSTM)                (None, 12, 100)           42000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                17024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# ...
# Total params: 59,057
# Trainable params: 59,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit model
history = model.fit(trainX, trainY, epochs=10, batch_size = 16, validation_split = 0.1, verbose =1)
# Out:
# Epoch 1/10
# 21/21 [==============================] - 0s 22ms/step - loss: 0.2947 - val_loss: 0.0589
# Epoch 2/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0594 - val_loss: 0.0839
# Epoch 3/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0477 - val_loss: 0.0559
# Epoch 4/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0455 - val_loss: 0.0816
# Epoch 5/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0333 - val_loss: 0.0319
# Epoch 6/10
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0425 - val_loss: 0.0490
# Epoch 7/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0483 - val_loss: 0.0445
# Epoch 8/10
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0536 - val_loss: 0.0375
# Epoch 9/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0406 - val_loss: 0.0648
# Epoch 10/10
# ...

# %%
#forecasting

n_future = 24
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods= n_future, freq = '1m')

forecast = model.predict(trainX[-n_future:])
forecast_copies = np.repeat(forecast, rnndf_training.shape[1], axis = -1)

y_pred_future_AEI = scaler.inverse_transform(forecast_copies)[:,0]
y_pred_future_DG = scaler.inverse_transform(forecast_copies)[:,1]
y_pred_future_BR = scaler.inverse_transform(forecast_copies)[:,2]
y_pred_future_HPI = scaler.inverse_transform(forecast_copies)[:,3]

# %%
print(y_pred_future_AEI)
# Out:
# [168.54504 169.21292 169.74844 170.21553 170.58157 170.90247 171.09729
#  171.24654 171.29118 171.29318 171.15529 170.90894 170.7083  170.54462
#  170.49756 170.76877 171.22179 171.78209 172.45555 173.19478 173.92644
#  174.58682 175.31026 176.10896]

# %%
print(y_pred_future_DG)
# Out:
# [32380.51  32517.742 32627.78  32723.754 32798.97  32864.906 32904.938
#  32935.6   32944.777 32945.188 32916.85  32866.234 32825.008 32791.375
#  32781.707 32837.434 32930.516 33045.645 33184.027 33335.92  33486.258
#  33621.953 33770.6   33934.715]

# %%
print(y_pred_future_BR)
# Out:
# [8.828121  8.896035  8.950491  8.997987  9.035209  9.067841  9.087651
#  9.102826  9.1073675 9.107571  9.093548  9.068499  9.048095  9.031451
#  9.026666  9.054244  9.100309  9.157286  9.225767  9.300938  9.375337
#  9.44249   9.516053  9.59727  ]

# %%
print(y_pred_future_HPI)
# Out:
# [118.04549  118.68657  119.20061  119.64896  120.00031  120.30835
#  120.49535  120.6386   120.68147  120.68339  120.55102  120.31456
#  120.121956 119.96485  119.91968  120.18001  120.614845 121.15267
#  121.79912  122.5087   123.211006 123.844894 124.539314 125.30597 ]

# %%
rnndf.tail()
# Out:
#         Date  AEI Index  Durable Goods Total  Bank Rate Value  \
# 371  2020-12      183.5         33239.000000         0.164286
# 372  2021-01      183.1         31962.000000         0.171429
# 373  2021-02      184.5         34056.333333         0.178571
# 374  2021-03      197.9         36150.666667         0.185714
# 375  2021-04      184.0         38245.000000         0.192857
#
#      House Price Index
# 371             130.06
# 372             130.96
# 373             130.90
# 374             133.05
# 375             131.45

# %%
forecast_dates = []
for time_i in forecast_period_dates:
    forecast_dates.append(time_i.date())

# %% [markdown]
# **Forecasting AEI Index**

# %%
rnndf_forecast_aei = pd.DataFrame({'Date':np.array(forecast_dates), 'AEI Index': y_pred_future_AEI})
rnndf_forecast_aei['Date']= pd.to_datetime(rnndf_forecast_aei['Date'])
rnndf_forecast_aei
# Out:
#          Date   AEI Index
# 0  2021-04-30  168.545044
# 1  2021-05-31  169.212921
# 2  2021-06-30  169.748444
# 3  2021-07-31  170.215530
# 4  2021-08-31  170.581573
# 5  2021-09-30  170.902466
# 6  2021-10-31  171.097290
# 7  2021-11-30  171.246536
# 8  2021-12-31  171.291183
# 9  2022-01-31  171.293182
# 10 2022-02-28  171.155289
# 11 2022-03-31  170.908936
# 12 2022-04-30  170.708298
# 13 2022-05-31  170.544617
# 14 2022-06-30  170.497559
# 15 2022-07-31  170.768768
# 16 2022-08-31  171.221786
# 17 2022-09-30  171.782089
# 18 2022-10-31  172.455551
# 19 2022-11-30  173.194778
# 20 2022-12-31  173.926437
# 21 2023-01-31  174.586823
# 22 2023-02-28  175.310257
# 23 2023-03-31  176.108963

# %%
original_aei = rnndf[['Date', 'AEI Index']]
original_aei['Date']=pd.to_datetime(original_aei['Date'])
original_aei = original_aei.loc[original_aei['Date'] >= '1990-01-1']

# %%
concatenate_forecast_original_AEI = pd.concat([original, rnndf_forecast_aei])
concatenate_forecast_original_AEI
# Out:
#          Date   AEI Index
# 0  1990-01-01   62.000000
# 1  1990-02-01   62.566667
# 2  1990-03-01   63.133333
# 3  1990-04-01   63.700000
# 4  1990-05-01   64.000000
# ..        ...         ...
# 19 2022-11-30  173.194778
# 20 2022-12-31  173.926437
# 21 2023-01-31  174.586823
# 22 2023-02-28  175.310257
# 23 2023-03-31  176.108963
#
# [400 rows x 2 columns]

# %%
file_name = 'AEI Index Original and Forecast.csv'

# saving the excel
concatenate_forecast_original_AEI.to_csv(file_name)

# %%
#plotting of data
plt.figure(figsize=(10,8))
plt.xlabel('Date')
plt.ylabel('AEI Index')
plt.title('AEI Index Original and Forecast')

sns.lineplot(concatenate_forecast_original_AEI['Date'], concatenate_forecast_original_AEI['AEI Index'])
sns.lineplot(rnndf_forecast_aei['Date'], rnndf_forecast_aei['AEI Index'], color = "blue")
# Out:
# <AxesSubplot:title={'center':'AEI Index Original and Forecast'}, xlabel='Date', ylabel='AEI Index'>

# %% [markdown]
# **Bank Rate Value Forecasting**

# %%
rnndf_forecast_br = pd.DataFrame({'Date':np.array(forecast_dates), 'Bank Rate Value': y_pred_future_BR})
rnndf_forecast_br['Date']= pd.to_datetime(rnndf_forecast_br['Date'])
rnndf_forecast_br
# Out:
#          Date  Bank Rate Value
# 0  2021-04-30         8.828121
# 1  2021-05-31         8.896035
# 2  2021-06-30         8.950491
# 3  2021-07-31         8.997987
# 4  2021-08-31         9.035209
# 5  2021-09-30         9.067841
# 6  2021-10-31         9.087651
# 7  2021-11-30         9.102826
# 8  2021-12-31         9.107368
# 9  2022-01-31         9.107571
# 10 2022-02-28         9.093548
# 11 2022-03-31         9.068499
# 12 2022-04-30         9.048095
# 13 2022-05-31         9.031451
# 14 2022-06-30         9.026666
# 15 2022-07-31         9.054244
# 16 2022-08-31         9.100309
# 17 2022-09-30         9.157286
# 18 2022-10-31         9.225767
# 19 2022-11-30         9.300938
# 20 2022-12-31         9.375337
# 21 2023-01-31         9.442490
# 22 2023-02-28         9.516053
# 23 2023-03-31         9.597270

# %%
original_br = rnndf[['Date', 'Bank Rate Value']]
original_br['Date']=pd.to_datetime(original_br['Date'])
original_br = original_br.loc[original_br['Date'] >= '1990-01-1']

# %%
concatenate_forecast_original_BR = pd.concat([original_br, rnndf_forecast_br])
concatenate_forecast_original_BR
# Out:
#          Date  Bank Rate Value
# 0  1990-01-01        13.880000
# 1  1990-02-01        13.880000
# 2  1990-03-01        13.880000
# 3  1990-04-01        13.880000
# 4  1990-05-01        13.880000
# ..        ...              ...
# 19 2022-11-30         9.300938
# 20 2022-12-31         9.375337
# 21 2023-01-31         9.442490
# 22 2023-02-28         9.516053
# 23 2023-03-31         9.597270
#
# [400 rows x 2 columns]

# %%
file_name = 'Bank Rate Value Original and Forecast.csv'

# saving the excel
concatenate_forecast_original_BR.to_csv(file_name)

# %%
#plotting of data
plt.figure(figsize=(10,8))
plt.xlabel('Date')
plt.ylabel('Bank Rate Value')
plt.title('Bank Rate Value Original and Forecast')

sns.lineplot(concatenate_forecast_original_BR['Date'], concatenate_forecast_original_BR['Bank Rate Value'])
sns.lineplot(rnndf_forecast_br['Date'], rnndf_forecast_br['Bank Rate Value'], color = "blue")
# Out:
# <AxesSubplot:title={'center':'Bank Rate Value Original and Forecast'}, xlabel='Date', ylabel='Bank Rate Value'>

# %% [markdown]
# **Durable Goods Total Forecasting**

# %%
rnndf_forecast_dg = pd.DataFrame({'Date':np.array(forecast_dates), 'Durable Goods Total': y_pred_future_DG})
rnndf_forecast_dg['Date']= pd.to_datetime(rnndf_forecast_dg['Date'])
rnndf_forecast_dg
# Out:
#          Date  Durable Goods Total
# 0  2021-04-30         32380.509766
# 1  2021-05-31         32517.742188
# 2  2021-06-30         32627.779297
# 3  2021-07-31         32723.753906
# 4  2021-08-31         32798.968750
# 5  2021-09-30         32864.906250
# 6  2021-10-31         32904.937500
# 7  2021-11-30         32935.601562
# 8  2021-12-31         32944.777344
# 9  2022-01-31         32945.187500
# 10 2022-02-28         32916.851562
# 11 2022-03-31         32866.234375
# 12 2022-04-30         32825.007812
# 13 2022-05-31         32791.375000
# 14 2022-06-30         32781.707031
# 15 2022-07-31         32837.433594
# 16 2022-08-31         32930.515625
# 17 2022-09-30         33045.644531
# 18 2022-10-31         33184.027344
# 19 2022-11-30         33335.921875
# 20 2022-12-31         33486.257812
# 21 2023-01-31         33621.953125
# 22 2023-02-28         33770.601562
# 23 2023-03-31         33934.714844

# %%
original_dg = rnndf[['Date', 'Durable Goods Total']]
original_dg['Date']=pd.to_datetime(original_dg['Date'])
original_dg = original_dg.loc[original_dg['Date'] >= '1990-01-1']

# %%
concatenate_forecast_original_DG = pd.concat([original_dg, rnndf_forecast_dg])
concatenate_forecast_original_DG
# Out:
#          Date  Durable Goods Total
# 0  1990-01-01         11792.000000
# 1  1990-02-01         11672.333333
# 2  1990-03-01         11552.666667
# 3  1990-04-01         11433.000000
# 4  1990-05-01         11298.000000
# ..        ...                  ...
# 19 2022-11-30         33335.921875
# 20 2022-12-31         33486.257812
# 21 2023-01-31         33621.953125
# 22 2023-02-28         33770.601562
# 23 2023-03-31         33934.714844
#
# [400 rows x 2 columns]

# %%
file_name = 'Durable Goods Total and Forecast.csv'

# saving the excel
concatenate_forecast_original_DG.to_csv(file_name)

# %%
#plotting of data
plt.figure(figsize=(10,8))
plt.xlabel('Date')
plt.ylabel('Durable Goods Total')
plt.title('Durable Goods Total Original and Forecast')

sns.lineplot(concatenate_forecast_original_DG['Date'], concatenate_forecast_original_DG['Durable Goods Total'])
sns.lineplot(rnndf_forecast_dg['Date'], rnndf_forecast_dg['Durable Goods Total'], color = "blue")
# Out:
# <AxesSubplot:title={'center':'Durable Goods Total Original and Forecast'}, xlabel='Date', ylabel='Durable Goods Total'>

# %% [markdown]
# **House Price Index Forecasting**

# %%
rnndf_forecast_hpi = pd.DataFrame({'Date':np.array(forecast_dates), 'House Price Index': y_pred_future_HPI})
rnndf_forecast_hpi['Date']= pd.to_datetime(rnndf_forecast_hpi['Date'])
rnndf_forecast_hpi
# Out:
#          Date  House Price Index
# 0  2021-04-30         118.045486
# 1  2021-05-31         118.686569
# 2  2021-06-30         119.200607
# 3  2021-07-31         119.648956
# 4  2021-08-31         120.000313
# 5  2021-09-30         120.308350
# 6  2021-10-31         120.495354
# 7  2021-11-30         120.638603
# 8  2021-12-31         120.681473
# 9  2022-01-31         120.683388
# 10 2022-02-28         120.551018
# 11 2022-03-31         120.314560
# 12 2022-04-30         120.121956
# 13 2022-05-31         119.964851
# 14 2022-06-30         119.919678
# 15 2022-07-31         120.180008
# 16 2022-08-31         120.614845
# 17 2022-09-30         121.152672
# 18 2022-10-31         121.799118
# 19 2022-11-30         122.508698
# 20 2022-12-31         123.211006
# 21 2023-01-31         123.844894
# 22 2023-02-28         124.539314
# 23 2023-03-31         125.305969

# %%
original_hpi = rnndf[['Date', 'House Price Index']]
original_hpi['Date']=pd.to_datetime(original_hpi['Date'])
original_hpi = original_hpi.loc[original_hpi['Date'] >= '1990-01-1']

# %%
concatenate_forecast_original_HPI = pd.concat([original_hpi, rnndf_forecast_hpi])
concatenate_forecast_original_HPI
# Out:
#          Date  House Price Index
# 0  1990-01-01          30.550000
# 1  1990-02-01          30.550000
# 2  1990-03-01          30.550000
# 3  1990-04-01          30.280000
# 4  1990-05-01          30.280000
# ..        ...                ...
# 19 2022-11-30         122.508698
# 20 2022-12-31         123.211006
# 21 2023-01-31         123.844894
# 22 2023-02-28         124.539314
# 23 2023-03-31         125.305969
#
# [400 rows x 2 columns]

# %%
file_name = 'House Price Index and Forecast.csv'

# saving the excel
concatenate_forecast_original_HPI.to_csv(file_name)

# %%
#plotting of data
plt.figure(figsize=(10,8))
plt.xlabel('Date')
plt.ylabel('House Price Index')
plt.title('House Price Index Original and Forecast')

sns.lineplot(concatenate_forecast_original_HPI['Date'], concatenate_forecast_original_HPI['House Price Index'])
sns.lineplot(rnndf_forecast_hpi['Date'], rnndf_forecast_hpi['House Price Index'], color = "blue")
# Out:
# <AxesSubplot:title={'center':'House Price Index Original and Forecast'}, xlabel='Date', ylabel='House Price Index'>

# %%
#saving all forecasting in a new csv file

merge_data_forecasting = reduce(lambda x,y: pd.merge(x,y, on= 'Date', how= 'outer'), 
                    [concatenate_forecast_original_AEI, concatenate_forecast_original_BR, concatenate_forecast_original_DG,
                    concatenate_forecast_original_HPI])
merge_data_forecasting = merge_data_forecasting.set_index('Date')


# saving the excel
file_name = 'Time Series Forecasting House Price Market UK.csv'
merge_data_forecasting.to_csv(file_name)
merge_data_forecasting
# Out:
#              AEI Index  Bank Rate Value  Durable Goods Total  \
# Date
# 1990-01-01   62.000000        13.880000         11792.000000
# 1990-02-01   62.566667        13.880000         11672.333333
# 1990-03-01   63.133333        13.880000         11552.666667
# 1990-04-01   63.700000        13.880000         11433.000000
# 1990-05-01   64.000000        13.880000         11298.000000
# ...                ...              ...                  ...
# 2022-11-30  173.194778         9.300938         33335.921875
# 2022-12-31  173.926437         9.375337         33486.257812
# 2023-01-31  174.586823         9.442490         33621.953125
# 2023-02-28  175.310257         9.516053         33770.601562
# 2023-03-31  176.108963         9.597270         33934.714844
#
#             House Price Index
# Date
# 1990-01-01          30.550000
# 1990-02-01          30.550000
# 1990-03-01          30.550000
# 1990-04-01          30.280000
# 1990-05-01          30.280000
# ...                       ...
# ...

# %% [markdown]
# # *End of the Time Series Forecasting on House Price Market in the UK Project by Nisa Suraya Binti Shahril (18108598)*
